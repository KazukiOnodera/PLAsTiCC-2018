# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
tr = pd.read_feather('../data/train_log.f')

# %%
tr
# Out:
#          object_id         mjd  passband         flux   flux_err  detected
# 0              615  59750.4229         2  -544.810303   3.622952         1
# 1              615  59750.4306         1  -816.434326   5.553370         1
# 2              615  59750.4383         3  -471.385529   3.801213         1
# 3              615  59750.4450         4  -388.984985  11.395031         1
# 4              615  59752.4070         2  -681.858887   4.041204         1
# 5              615  59752.4147         1 -1061.457031   6.472994         1
# 6              615  59752.4224         3  -524.954590   3.552751         1
# 7              615  59752.4334         4  -393.480225   3.599346         1
# 8              615  59752.4435         5  -355.886780  10.421921         1
# 9              615  59767.2968         2  -548.013550   3.462291         1
# 10             615  59767.3045         1  -815.188599   5.293019         1
# ...

# %%
tr.groupby('object_id').flux.describe()
# Out:
#            count         mean          std          min         25%  \
# object_id
# 615        352.0  -123.096998   394.109851 -1100.440063 -405.626648
# 713        350.0    -1.423351     6.471144   -14.735178   -6.905373
# 730        330.0     2.267434     8.022239   -19.159811   -1.034406
# 745        351.0     8.909206    27.558208   -15.494463   -0.695045
# 1124       352.0     7.145702    20.051722   -16.543753   -0.201275
# 1227       330.0     0.367212     4.962633   -12.695161   -1.399707
# 1598       352.0    30.333023   167.317942   -13.854152   -1.473178
# 1632       352.0     1.760026     5.273147   -14.525748   -0.576212
# 1920       255.0    19.228827    48.004394   -13.367912   -0.518243
# 1926       255.0    -0.085210     6.288463   -52.764721   -1.937381
# 2072       351.0     1.738064     4.798681   -18.000116   -0.868077
# 2103       352.0    11.319435    36.182796   -17.384005   -0.987065
# 2300       351.0     2.245681     5.721734   -17.098705   -0.652726
# ...
