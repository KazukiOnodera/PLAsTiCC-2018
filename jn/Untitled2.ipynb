# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
SUBMIT_FILE_PATH = '../output/1015-3.csv.gz'

# %%
sub = pd.read_csv(SUBMIT_FILE_PATH)

# %%
sub.iloc[:, 1:].describe().iloc[3:]
# Out:
#       class_6  class_15  class_16  class_42  class_52  class_53  class_62  \
# min  0.000002  0.000001  0.000001  0.000002  0.000002  0.000002  0.000001
# 25%  0.000438  0.004906  0.000331  0.042380  0.004031  0.001323  0.005428
# 50%  0.000776  0.013070  0.000635  0.097829  0.009265  0.002029  0.012857
# 75%  0.001583  0.036464  0.001555  0.198694  0.020227  0.003112  0.031185
# max  0.995176  0.993997  0.999909  0.990667  0.702625  0.900506  0.933628
#
#          class_64      class_65      class_67  class_88  class_90  class_92  \
# min  2.691637e-07  2.415116e-07  8.187380e-07  0.000002  0.000001  0.000003
# 25%  4.999402e-04  5.872163e-04  2.331315e-03  0.000877  0.278537  0.000271
# 50%  1.539993e-03  1.379110e-03  5.460712e-03  0.002551  0.687848  0.000458
# 75%  5.300211e-03  3.334170e-03  1.276958e-02  0.010164  0.837903  0.000836
# max  9.636386e-01  9.995741e-01  7.996630e-01  0.999660  0.995769  0.998476
#
#          class_95  class_99
# min  4.119074e-07  0.000090
# ...

# %%
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(sub.iloc[:, 1:].describe().iloc[3:], annot=True, fmt="d", linewidths=.5, ax=ax); plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8ffe594f375d> in <module>()
#       1 f, ax = plt.subplots(figsize=(9, 6))
# ----> 2 sns.heatmap(sub.iloc[:, 1:].describe().iloc[3:], annot=True, fmt="d", linewidths=.5, ax=ax); plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     324         # Annotate the cells with the formatted values
#     325         if self.annot:
# --> 326             self._annotate_heatmap(ax, mesh)
# ...

# %%
sub.iloc[:, 1:].hist(bins=50, figsize=(16, 12))
plt.show()
